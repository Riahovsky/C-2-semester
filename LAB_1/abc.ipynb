# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#### Сравнение трёх стратегий в случае равномерного распределения
x = np.array([48,48,46,47,47,              51,51,49,50,51,              60,59,61, 59, 57,              149, 161,150,142,147,                 97,103,101,105,100    ])
y = np.array([100,100,100,100,100,     1000,1000,1000,1000,1000,    10000,10000,10000,10000,10000,   100000, 100000, 100000, 100000, 100000, 50000,50000,50000,50000,50000])


A = np.vstack([x, np.ones(len(x))]).T
m, c = np.linalg.lstsq(A, y, rcond=None)[0]
plt.plot(x, y, '.', label='A', markersize=10)
plt.plot(x, m * x + c, 'c', label='A')


x = np.array([53,50,49,50,48,                48,54,49,49,51,            56,63,60,57,59,                179, 163,172,160,175,                    109,113,115,111,111    ])
y = np.array([100,100,100,100,100,     1000,1000,1000,1000,1000,    10000,10000,10000,10000,10000,   100000, 100000, 100000, 100000, 100000, 50000,50000,50000,50000,50000])

A = np.vstack([x, np.ones(len(x))]).T
m, c = np.linalg.lstsq(A, y, rcond=None)[0]
plt.plot(x, y ,'.', label='B', markersize=10)
plt.plot(x, m * x + c, 'r', label='B'
)
x = np.array([51,50,49,51,53,             64, 62, 59,57,64,          76, 74,72, 80,74,                       280, 291,283,318,289,     171,175, 177, 184,172 ])
y = np.array([100,100,100,100,100,     1000,1000,1000,1000,1000,    10000,10000,10000,10000,10000,   100000, 100000, 100000, 100000, 100000, 50000,50000,50000,50000,50000])


A = np.vstack([x, np.ones(len(x))]).T
m, c = np.linalg.lstsq(A, y, rcond=None)[0]
plt.plot(x, y ,'.', label='C', markersize=10)
plt.plot(x, m * x + c, 'y', label='C')

plt.legend()
plt.show()
